# %% [markdown]
# # Custom Training StyleGan2-ADA

# %% [markdown]
# StyleGAN2-ADA only work with Tensorflow 1. Run the next cell before anything else to make sure we’re using TF1 and not TF2.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Sun Dec  6 16:57:29 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Install Repo to Google Drive
#
# Colab is a little funky with training. I’ve found the best way to do this is to install the repo directly into your Google Drive folder.
#
# First, mount your Drive to the Colab notebook:

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, run this cell. If you’re already installed the repo, it will skip the installation process and change into the repo’s directory. If you haven’t installed it, it will install all the files necessary.

# %%
import os
if os.path.isdir("/content/drive/My Drive/colab-sg2-ada"):
    # %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
else:
    #install script
    # %cd "/content/drive/My Drive/"
    # !mkdir colab-sg2-ada
    # %cd colab-sg2-ada
    # !git clone https://github.com/dvschultz/stylegan2-ada
    # %cd stylegan2-ada
    # !mkdir downloads
    # !mkdir datasets
# Out:
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %%
 # %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git checkout origin/main -- train.py

# %% [markdown]
# ## Convert dataset to .tfrecords

# %% [markdown]
# **Note: You only need to do this once per dataset. If you have already run this and are returning to conntinue training, skip these cells.**
#
# Next we need to convert our image dataset to a format that StyleGAN2-ADA can read from. There are two options here. You can upload your dataset directly to Colab (as a zipped file), or you can upload it to Drive directly and read it from there.

# %%
#if you manually uploaded your dataset to Colab, unzip it
zip_path = "/content/drive/MyDrive/Metis/Project5/Data/flag_512.zip"

# !unzip {zip_path} -d /content/drive/MyDrive/Metis/Project5/Data/

# %% [markdown]
# Now that your image dataset is uploaded, we need to convert it to the `.tfrecords` format.
#
# Depending on the resolution of your images and how many you have, this can take a while.

# %%
#update this to the path to your image folder
dataset_path = "/content/drive/MyDrive/Metis/Project5/Data/flag_512"
#give your dataset a name
dataset_name = "flags1"

#you don't need to edit anything here
# !python dataset_tool.py create_from_images ./datasets/{dataset_name} {dataset_path}

# %% [markdown]
# ## Train a custom model
#
# We’re ready to start training! There are numerous arguments to training, what’s listed below are the most popular options. To see all the options, run the following cell.

# %%
# !python train.py --help

# %%
dataset_name = "flags1"
# running it for the first time? set it to ffhq(+resolution)
# resuming? get the path to your latest .pkl file and use that
resume_from = '/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00013-flags1-mirror-11gb-gpu-gamma50-ada-target0.4-blit-resumecustom/network-snapshot-000176.pkl'

#!python train.py --outdir ./results --snap={snapshot_count} --cfg=11gb-gpu --data=./datasets/{dataset_name} --augpipe={augs} --mirror={mirrored} --mirrory={mirroredY} --metrics={metric_list} --resume={resume_from} --augpipe="bg"
# !python train.py --outdir ./results --snap=4 --cfg=11gb-gpu --data=./datasets/{dataset_name} --mirror=True --mirrory=False --metrics=None --resume={resume_from} --aug=ada --target=0.2 --augpipe="blit" --gamma=50
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x885e000 @  0x7f5309505001 0x7f530672e765 0x7f5306792bb0 0x7f5306794a4f 0x7f530682b048 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f5137060000 @  0x7f53095031e7 0x7f530672e5e1 0x7f5306792c78 0x7f5306792f37 0x7f530682af28 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f503605e000 @  0x7f53095031e7 0x7f530672e5e1 0x7f5306792c78 0x7f5306792f37 0x7f52c47980c5 0x7f52c411b902 0x7f52c411beb2 0x7f52c40d4c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
#
# Training options:
# {
#   "G_args": {
#     "func_name": "training.networks.G_main",
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "mapping_layers": 8,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "D_args": {
#     "func_name": "training.networks.D_main",
#     "mbstd_group_size": 8,
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.002
#   },
#   "D_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.002
#   },
#   "loss_args": {
#     "func_name": "training.loss.stylegan2",
#     "r1_gamma": 50.0
#   },
#   "augment_args": {
#     "class_name": "training.augment.AdaptiveAugment",
#     "tune_heuristic": "rt",
#     "tune_target": 0.2,
#     "apply_func": "training.augment.augment_pipeline",
#     "apply_args": {
#       "xflip": 1,
#       "rotate90": 1,
#       "xint": 1
#     },
#     "tune_kimg": 100
#   },
#   "num_gpus": 1,
#   "image_snapshot_ticks": 4,
#   "network_snapshot_ticks": 4,
#   "train_dataset_args": {
#     "path": "./datasets/flags1",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 512,
#     "mirror_augment": true,
#     "mirror_augment_v": false
#   },
#   "metric_arg_list": [],
#   "metric_dataset_args": {
#     "path": "./datasets/flags1",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 512,
#     "mirror_augment": true,
#     "mirror_augment_v": false
#   },
#   "total_kimg": 25000,
#   "minibatch_size": 8,
#   "minibatch_gpu": 8,
#   "G_smoothing_kimg": 10,
#   "G_smoothing_rampup": null,
#   "resume_pkl": "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00013-flags1-mirror-11gb-gpu-gamma50-ada-target0.4-blit-resumecustom/network-snapshot-000176.pkl",
#   "run_dir": "./results/00014-flags1-mirror-11gb-gpu-gamma50-ada-target0.2-blit-resumecustom"
# }
#
# Output directory:  ./results/00014-flags1-mirror-11gb-gpu-gamma50-ada-target0.2-blit-resumecustom
# Training data:     ./datasets/flags1
# Training length:   25000 kimg
# Resolution:        512
# Number of GPUs:    1
#
# Creating output directory...
# Loading training set...
# tcmalloc: large alloc 4294967296 bytes == 0x879c000 @  0x7f5309505001 0x7f530672e765 0x7f5306792bb0 0x7f5306794a4f 0x7f530682b048 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f4f2786a000 @  0x7f53095031e7 0x7f530672e5e1 0x7f5306792c78 0x7f5306792f37 0x7f530682af28 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f4f2786a000 @  0x7f53095031e7 0x7f530672e5e1 0x7f5306792c78 0x7f5306792f37 0x7f52c47980c5 0x7f52c411b902 0x7f52c411beb2 0x7f52c40d4c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
# Resuming from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00013-flags1-mirror-11gb-gpu-gamma50-ada-target0.4-blit-resumecustom/network-snapshot-000176.pkl"
#
# G                             Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# epochs                        1         ()                  ()
# epochs_1                      1         ()                  ()
# G_mapping/Normalize           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Dense2              262656    (?, 512)            (512, 512)
# G_mapping/Dense3              262656    (?, 512)            (512, 512)
# G_mapping/Dense4              262656    (?, 512)            (512, 512)
# G_mapping/Dense5              262656    (?, 512)            (512, 512)
# G_mapping/Dense6              262656    (?, 512)            (512, 512)
# G_mapping/Dense7              262656    (?, 512)            (512, 512)
# G_mapping/Broadcast           -         (?, 16, 512)        -
# dlatent_avg                   -         (512,)              -
# Truncation/Lerp               -         (?, 16, 512)        -
# G_synthesis/4x4/Const         8192      (?, 512, 4, 4)      (1, 512, 4, 4)
# G_synthesis/4x4/Conv          2622465   (?, 512, 4, 4)      (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB         264195    (?, 3, 4, 4)        (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up      2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Conv1         2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Upsample      -         (?, 3, 8, 8)        -
# G_synthesis/8x8/ToRGB         264195    (?, 3, 8, 8)        (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up    2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Conv1       2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Upsample    -         (?, 3, 16, 16)      -
# G_synthesis/16x16/ToRGB       264195    (?, 3, 16, 16)      (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up    2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Conv1       2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Upsample    -         (?, 3, 32, 32)      -
# G_synthesis/32x32/ToRGB       264195    (?, 3, 32, 32)      (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up    2622465   (?, 512, 64, 64)    (3, 3, 512, 512)
# G_synthesis/64x64/Conv1       2622465   (?, 512, 64, 64)    (3, 3, 512, 512)
# G_synthesis/64x64/Upsample    -         (?, 3, 64, 64)      -
# G_synthesis/64x64/ToRGB       264195    (?, 3, 64, 64)      (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up  1442561   (?, 256, 128, 128)  (3, 3, 512, 256)
# G_synthesis/128x128/Conv1     721409    (?, 256, 128, 128)  (3, 3, 256, 256)
# G_synthesis/128x128/Upsample  -         (?, 3, 128, 128)    -
# G_synthesis/128x128/ToRGB     132099    (?, 3, 128, 128)    (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up  426369    (?, 128, 256, 256)  (3, 3, 256, 128)
# G_synthesis/256x256/Conv1     213249    (?, 128, 256, 256)  (3, 3, 128, 128)
# G_synthesis/256x256/Upsample  -         (?, 3, 256, 256)    -
# G_synthesis/256x256/ToRGB     66051     (?, 3, 256, 256)    (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up  139457    (?, 64, 512, 512)   (3, 3, 128, 64)
# G_synthesis/512x512/Conv1     69761     (?, 64, 512, 512)   (3, 3, 64, 64)
# G_synthesis/512x512/Upsample  -         (?, 3, 512, 512)    -
# G_synthesis/512x512/ToRGB     33027     (?, 3, 512, 512)    (1, 1, 64, 3)
# ---                           ---       ---                 ---
# Total                         30276585
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 512, 512)    -
# labels_in            -         (?, 0)              -
# 512x512/FromRGB      256       (?, 64, 512, 512)   (1, 1, 3, 64)
# 512x512/Conv0        36928     (?, 64, 512, 512)   (3, 3, 64, 64)
# 512x512/Conv1_down   73856     (?, 128, 256, 256)  (3, 3, 64, 128)
# 512x512/Skip         8192      (?, 128, 256, 256)  (1, 1, 64, 128)
# 256x256/Conv0        147584    (?, 128, 256, 256)  (3, 3, 128, 128)
# 256x256/Conv1_down   295168    (?, 256, 128, 128)  (3, 3, 128, 256)
# 256x256/Skip         32768     (?, 256, 128, 128)  (1, 1, 128, 256)
# 128x128/Conv0        590080    (?, 256, 128, 128)  (3, 3, 256, 256)
# 128x128/Conv1_down   1180160   (?, 512, 64, 64)    (3, 3, 256, 512)
# 128x128/Skip         131072    (?, 512, 64, 64)    (1, 1, 256, 512)
# 64x64/Conv0          2359808   (?, 512, 64, 64)    (3, 3, 512, 512)
# 64x64/Conv1_down     2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 64x64/Skip           262144    (?, 512, 32, 32)    (1, 1, 512, 512)
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 32x32/Skip           262144    (?, 512, 16, 16)    (1, 1, 512, 512)
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 16x16/Skip           262144    (?, 512, 8, 8)      (1, 1, 512, 512)
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 8x8/Conv1_down       2359808   (?, 512, 4, 4)      (3, 3, 512, 512)
# 8x8/Skip             262144    (?, 512, 4, 4)      (1, 1, 512, 512)
# 4x4/MinibatchStddev  -         (?, 513, 4, 4)      -
# 4x4/Conv             2364416   (?, 512, 4, 4)      (3, 3, 513, 512)
# 4x4/Dense0           4194816   (?, 512)            (8192, 512)
# Output               513       (?, 1)              (512, 1)
# ---                  ---       ---                 ---
# Total                28982849
#
# Exporting sample images...
# Replicating networks across 1 GPUs...
# Initializing augmentations...
# Setting up optimizers...
# Constructing training graph...
# Finalizing training ops...
# Initializing metrics...
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 2m 07s       sec/tick 24.7    sec/kimg 772.41  maintenance 101.8  gpumem 10.0  augment 0.000
# tick 1     kimg 4.0      time 19m 47s      sec/tick 1043.2  sec/kimg 260.79  maintenance 17.0   gpumem 10.0  augment 0.039
# tick 2     kimg 8.0      time 37m 11s      sec/tick 1043.8  sec/kimg 260.94  maintenance 0.0    gpumem 10.0  augment 0.079
# tick 3     kimg 12.0     time 54m 35s      sec/tick 1044.5  sec/kimg 261.13  maintenance 0.0    gpumem 10.0  augment 0.118
# tick 4     kimg 16.0     time 1h 12m 01s   sec/tick 1045.8  sec/kimg 261.44  maintenance 0.0    gpumem 10.0  augment 0.157
# tick 5     kimg 20.0     time 1h 29m 32s   sec/tick 1045.6  sec/kimg 261.40  maintenance 5.6    gpumem 10.0  augment 0.196
# tick 6     kimg 24.0     time 1h 46m 58s   sec/tick 1046.1  sec/kimg 261.52  maintenance 0.0    gpumem 10.0  augment 0.235
# tick 7     kimg 28.0     time 2h 04m 25s   sec/tick 1046.5  sec/kimg 261.63  maintenance 0.0    gpumem 10.0  augment 0.275
# tick 8     kimg 32.0     time 2h 21m 53s   sec/tick 1048.0  sec/kimg 262.00  maintenance 0.0    gpumem 10.0  augment 0.315
# tick 9     kimg 36.0     time 2h 39m 26s   sec/tick 1047.7  sec/kimg 261.93  maintenance 5.7    gpumem 10.0  augment 0.355
# tick 10    kimg 40.0     time 2h 56m 54s   sec/tick 1048.2  sec/kimg 262.04  maintenance 0.0    gpumem 10.0  augment 0.394
# tick 11    kimg 44.0     time 3h 14m 23s   sec/tick 1048.5  sec/kimg 262.13  maintenance 0.0    gpumem 10.0  augment 0.433
# tick 12    kimg 48.0     time 3h 31m 53s   sec/tick 1050.1  sec/kimg 262.52  maintenance 0.0    gpumem 10.0  augment 0.473
# tick 13    kimg 52.0     time 3h 49m 28s   sec/tick 1049.5  sec/kimg 262.37  maintenance 5.8    gpumem 10.0  augment 0.513
# tick 14    kimg 56.0     time 4h 06m 58s   sec/tick 1050.1  sec/kimg 262.52  maintenance 0.0    gpumem 10.0  augment 0.553
# tick 15    kimg 60.0     time 4h 24m 29s   sec/tick 1050.6  sec/kimg 262.65  maintenance 0.0    gpumem 10.0  augment 0.593
# tick 16    kimg 64.0     time 4h 42m 01s   sec/tick 1051.8  sec/kimg 262.95  maintenance 0.0    gpumem 10.0  augment 0.631
# tick 17    kimg 68.0     time 4h 59m 37s   sec/tick 1051.2  sec/kimg 262.81  maintenance 5.6    gpumem 10.0  augment 0.671
# tick 18    kimg 72.0     time 5h 17m 09s   sec/tick 1051.6  sec/kimg 262.91  maintenance 0.0    gpumem 10.0  augment 0.711
# tick 19    kimg 76.0     time 5h 34m 41s   sec/tick 1052.1  sec/kimg 263.03  maintenance 0.0    gpumem 10.0  augment 0.751
# tick 20    kimg 80.0     time 5h 52m 14s   sec/tick 1053.2  sec/kimg 263.30  maintenance 0.0    gpumem 10.0  augment 0.789
# tick 21    kimg 84.0     time 6h 09m 53s   sec/tick 1052.6  sec/kimg 263.16  maintenance 5.6    gpumem 10.0  augment 0.829
# tick 22    kimg 88.0     time 6h 27m 26s   sec/tick 1053.0  sec/kimg 263.24  maintenance 0.0    gpumem 10.0  augment 0.868
# tick 23    kimg 92.0     time 6h 44m 59s   sec/tick 1053.3  sec/kimg 263.32  maintenance 0.0    gpumem 10.0  augment 0.908
# tick 24    kimg 96.0     time 7h 02m 33s   sec/tick 1054.5  sec/kimg 263.63  maintenance 0.0    gpumem 10.0  augment 0.947

# %% [markdown]
# ### While it’s training...
# **Once the above cell is running you should be training!**
#
# Don’t close this tab! Colab needs to be open and running in order to continue training. Every ~15min or so a new line should get added to your output, indicated its still training. Depending on you `snapshot_count` setting you should see the results folder in your Google drive folder fill with both samples (`fakesXXXXXx.jpg`) and model weights (`network-snapshot-XXXXXX.pkl`). The samples are worth looking at while it trains but don’t get too worried about each individual sample.
#
# If you chose a metric, you will also see scores for each snapshot. Don’t obsess over these! they are a guide, it can go up or down slightly for each snapshot. What you want to see is a gradual lowering of the score over time.
#
# Once Colab shuts off, you can Reconnect the notebook and re-run every cell from top to bottom. Make sure you update the `resume_from` path to continue training from the latest model.
