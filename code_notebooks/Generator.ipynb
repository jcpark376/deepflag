# %% [markdown]
# # Custom Training StyleGan2-ADA

# %% [markdown]
# StyleGAN2-ADA only work with Tensorflow 1. Run the next cell before anything else to make sure we’re using TF1 and not TF2.

# %%
# %tensorflow_version 1.x

# %%
# !nvidia-smi
# Out:
# Mon Dec  7 01:18:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
# %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"

# import os
# if os.path.isdir("/content/drive/My Drive/colab-sg2-ada"):
#     %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
# Out:
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %% [markdown]
# ## Generate Images
#
# Playing around with many functions in generate.py

# %%
output_dir = '/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/outputs/00006-000176'
model='/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00006-flags1-mirror-11gb-gpu-gamma40-ada-target0.4-blit-resumeffhq512/network-snapshot-000176.pkl'

# !python generate.py generate-images --network={model} --seeds=0-1000 --trunc=1 --create-grid --outdir={output_dir}
# Out:
# Loading networks from "/content/drive/MyDrive/colab-sg2-ada/stylegan2-ada/results/00006-flags1-mirror-11gb-gpu-gamma40-ada-target0.4-blit-resumeffhq512/network-snapshot-000176.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 0 (0/1001) ...
# Generating image for seed 1 (1/1001) ...
# Generating image for seed 2 (2/1001) ...
# Generating image for seed 3 (3/1001) ...
# Generating image for seed 4 (4/1001) ...
# Generating image for seed 5 (5/1001) ...
# Generating image for seed 6 (6/1001) ...
# Generating image for seed 7 (7/1001) ...
# Generating image for seed 8 (8/1001) ...
# Generating image for seed 9 (9/1001) ...
# Generating image for seed 10 (10/1001) ...
# Generating image for seed 11 (11/1001) ...
# Generating image for seed 12 (12/1001) ...
# Generating image for seed 13 (13/1001) ...
# Generating image for seed 14 (14/1001) ...
# ...

# %%
# pip install opensimplex
